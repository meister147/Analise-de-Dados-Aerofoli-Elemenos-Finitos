# %% [markdown]
# <a href="https://colab.research.google.com/github/meister147/Analise-de-Dados-Aerofoli-Elemenos-Finitos/blob/main/Aerofoli_Analise_Eliezer_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Mounted at /content/drive

# %%
data1 = pd.read_csv("/content/drive/MyDrive/exportELEM1.csv", decimal=',')
data1 = data1.astype(float)

data2 = pd.read_csv("/content/drive/MyDrive/exportELEM2.csv", decimal=',')
data2 = data2.astype(float)

data3 = pd.read_csv("/content/drive/MyDrive/exportELEM3.csv", decimal=',')
data3 = data3.astype(float)

data4 = pd.read_csv("/content/drive/MyDrive/exportELEM4.csv", decimal=',')
data4 = data4.astype(float)

data5 = pd.read_csv("/content/drive/MyDrive/exportELEM5.csv", decimal=',')
data5 = data5.astype(float)

data6 = pd.read_csv("/content/drive/MyDrive/exportELEM6.csv", decimal=',')
data6 = data6.astype(float)

data7 = pd.read_csv("/content/drive/MyDrive/exportELEM7.csv", decimal=',')
data7 = data7.astype(float)

data8 = pd.read_csv("/content/drive/MyDrive/exportELEM8.csv", decimal=',')
data8 = data8.astype(float)

# %% [markdown]
# #**GRÁFICOS**

# %% [markdown]
# ![Screenshot_1.png](data:image/png;base64,...)
#
# Essas foram as retas traçadas para o cálculo do perfil da velocidade!

# %% [markdown]
# #1. Graph 1

# %%
fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data1, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax1, color='b')
sns.lineplot(data=data1, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("X Metros")
ax1.set_xticklabels(data1['X [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data1, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax1, color='b')
sns.lineplot(data=data1, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("Y Metros")
ax1.set_xticklabels(data1[' Y [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

# %% [markdown]
# #Graph 2

# %%
fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data2, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax1, color='b')
sns.lineplot(data=data2, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("X Metros")
ax1.set_xticklabels(data2['X [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data2, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax1, color='b')
sns.lineplot(data=data2, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("Y Metros")
ax1.set_xticklabels(data2[' Y [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

# %% [markdown]
# #Graph 3

# %%
fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data3, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax1, color='b')
sns.lineplot(data=data3, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("X Metros")
ax1.set_xticklabels(data3['X [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data3, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax1, color='b')
sns.lineplot(data=data3, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("Y Metros")
ax1.set_xticklabels(data3[' Y [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

# %% [markdown]
# #Graph 4

# %%
fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data4, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax1, color='b')
sns.lineplot(data=data4, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("X Metros")
ax1.set_xticklabels(data4['X [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data4, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax1, color='b')
sns.lineplot(data=data4, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("Y Metros")
ax1.set_xticklabels(data4[' Y [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

# %% [markdown]
# #Graph 5

# %%
fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data5, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax1, color='b')
sns.lineplot(data=data5, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("X Metros")
ax1.set_xticklabels(data5['X [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data5, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax1, color='b')
sns.lineplot(data=data5, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("Y Metros")
ax1.set_xticklabels(data5[' Y [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

# %% [markdown]
# #Graph 6

# %%
fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data6, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax1, color='b')
sns.lineplot(data=data6, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("X Metros")
ax1.set_xticklabels(data6['X [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data6, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax1, color='b')
sns.lineplot(data=data6, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("Y Metros")
ax1.set_xticklabels(data6[' Y [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

# %% [markdown]
# #Graph 7

# %%
fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data7, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax1, color='b')
sns.lineplot(data=data7, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("X Metros")
ax1.set_xticklabels(data7['X [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data7, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax1, color='b')
sns.lineplot(data=data7, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("Y Metros")
ax1.set_xticklabels(data7[' Y [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

# %% [markdown]
# #Graph 8

# %%
fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data8, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax1, color='b')
sns.lineplot(data=data8, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("X Metros")
ax1.set_xticklabels(data8['X [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

fig, ax1 = plt.subplots()
ax2=ax1.twinx()
sns.lineplot(data=data8, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax1, color='b')
sns.lineplot(data=data8, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax2, color='orange')
ax1.set_ylabel("Velocidade (m/s)", color = 'b')
ax1.set_xlabel("Y Metros")
ax1.set_xticklabels(data8[' Y [ m ]'], rotation='vertical', size=8)
ax2.set_ylabel('Pressão (Pa)', color='orange')
plt.grid()
plt.show()

# %% [markdown]
# #GRAPH 1 + 2

# %%
fig, ax = plt.subplots()
sns.lineplot(data=data1, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax, color='b', label=1)
sns.lineplot(data=data2, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax, color='g', label=2)
ax.set_ylabel("Velocidade (m/s)", color = 'b')
ax.set_xlabel("X Metros")
ax.legend()
plt.grid()
plt.show()

fig, ax = plt.subplots()
sns.lineplot(data=data1, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax, color='b', label=1)
sns.lineplot(data=data2, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax, color='g', label=2)
ax.set_ylabel("Velocidade (m/s)", color = 'b')
ax.set_xlabel("Y Metros")
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data=data1, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax, color='b', label=1)
sns.lineplot(data=data2, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax, color='g', label=2)
ax.set_ylabel("Pressao (Pa)", color = 'b')
ax.set_xlabel("X Metros")
ax.legend()
plt.grid()
plt.show()

fig, ax = plt.subplots()
sns.lineplot(data=data1, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax, color='b', label=1)
sns.lineplot(data=data2, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax, color='g', label=2)
ax.set_ylabel("Pressao (Pa)", color = 'b')
ax.set_xlabel("Y Metros")
ax.legend()
plt.grid()
plt.show()

# %% [markdown]
# #Graph 3 + 4

# %%
fig, ax = plt.subplots()
sns.lineplot(data=data3, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax, color='b', label=3)
sns.lineplot(data=data4, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax, color='g', label=4)
ax.set_ylabel("Velocidade (m/s)", color = 'b')
ax.set_xlabel("X Metros")
ax.legend()
plt.grid()
plt.show()

fig, ax = plt.subplots()
sns.lineplot(data=data3, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax, color='b', label=3)
sns.lineplot(data=data4, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax, color='g', label=4)
ax.set_ylabel("Velocidade (m/s)", color = 'b')
ax.set_xlabel("Y Metros")
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data=data3, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax, color='b', label=3)
sns.lineplot(data=data4, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax, color='g', label=4)
ax.set_ylabel("Pressao (Pa)", color = 'b')
ax.set_xlabel("X Metros")
ax.legend()
plt.grid()
plt.show()

fig, ax = plt.subplots()
sns.lineplot(data=data3, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax, color='b', label=3)
sns.lineplot(data=data4, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax, color='g', label=4)
ax.set_ylabel("Pressao (Pa)", color = 'b')
ax.set_xlabel("Y Metros")
ax.legend()
plt.grid()
plt.show()

# %% [markdown]
# #Graph 5 + 6

# %%
fig, ax = plt.subplots()
sns.lineplot(data=data5, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax, color='b', label=5)
sns.lineplot(data=data6, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax, color='g', label=6)
ax.set_ylabel("Velocidade (m/s)", color = 'b')
ax.set_xlabel("X Metros")
ax.legend()
plt.grid()
plt.show()

fig, ax = plt.subplots()
sns.lineplot(data=data5, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax, color='b', label=5)
sns.lineplot(data=data6, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax, color='g', label=6)
ax.set_ylabel("Velocidade (m/s)", color = 'b')
ax.set_xlabel("Y Metros")
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data=data5, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax, color='b', label=5)
sns.lineplot(data=data6, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax, color='g', label=6)
ax.set_ylabel("Pressao (Pa)", color = 'b')
ax.set_xlabel("X Metros")
ax.legend()
plt.grid()
plt.show()

fig, ax = plt.subplots()
sns.lineplot(data=data5, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax, color='b', label=5)
sns.lineplot(data=data6, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax, color='g', label=6)
ax.set_ylabel("Pressao (Pa)", color = 'b')
ax.set_xlabel("Y Metros")
ax.legend()
plt.grid()
plt.show()

# %% [markdown]
# #GRAPH 7 + 8

# %%
fig, ax = plt.subplots()
sns.lineplot(data=data7, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax, color='b', label=7)
sns.lineplot(data=data8, y=' Velocity u [ m s^-1 ]', x='X [ m ]', ax=ax, color='g', label=8)
ax.set_ylabel("Velocidade (m/s)", color = 'b')
ax.set_xlabel("X Metros")
ax.legend()
plt.grid()
plt.show()

fig, ax = plt.subplots()
sns.lineplot(data=data7, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax, color='b', label=7)
sns.lineplot(data=data8, y=' Velocity u [ m s^-1 ]', x=' Y [ m ]', ax=ax, color='g', label=8)
ax.set_ylabel("Velocidade (m/s)", color = 'b')
ax.set_xlabel("Y Metros")
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(data=data7, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax, color='b', label=7)
sns.lineplot(data=data8, y=' Pressure [ Pa ]', x='X [ m ]', ax=ax, color='g', label=8)
ax.set_ylabel("Pressão (Pa)", color = 'b')
ax.set_xlabel("X Metros")
ax.legend()
plt.grid()
plt.show()

fig, ax = plt.subplots()
sns.lineplot(data=data7, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax, color='b', label=7)
sns.lineplot(data=data8, y=' Pressure [ Pa ]', x=' Y [ m ]', ax=ax, color='g', label=8)
ax.set_ylabel("Pressão (Pa)", color = 'b')
ax.set_xlabel("Y Metros")
ax.legend()
plt.grid()
plt.show()
